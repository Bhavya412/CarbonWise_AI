# %% [markdown]
# # 03. Model Training & Comparison
# Training Linear Regression, Random Forest, and Gradient Boosting Regressors.

# %%
import sys
sys.path.append("..")
from train import main as train_main
train_main()
